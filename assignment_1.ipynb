# %%
#QUESTION-1A

import pandas as pd
scores=[90,70,54,77,40,49,60,99,44,97,67,87,48,93,100,59,78,98,30,84]
grade=[]
result=[]
for i in scores:
  if i>=90:
    grade.append('A+')
  elif i>=80:
    grade.append('A')
  elif i>=60:
    grade.append('B+')
  elif i>=50:
    grade.append('B')
  else:
    grade.append('F')
for i in scores:
  if i>=50:
    result.append('Pass')
  else:
    result.append('Fail')
df=pd.DataFrame({'Student':[f"Student {i}" for i in range(1,21)],'Scores':scores,'Grade':grade,'Result':result})
print(df)
print("Overall performance:")
print("Average:",df['Scores'].mean())
print("Highest mark:",df['Scores'].max())
print("Lowest score:",df['Scores'].min())
# Out:
#        Student  Scores Grade Result
# 0    Student 1      90    A+   Pass
# 1    Student 2      70    B+   Pass
# 2    Student 3      54     B   Pass
# 3    Student 4      77    B+   Pass
# 4    Student 5      40     F   Fail
# 5    Student 6      49     F   Fail
# 6    Student 7      60    B+   Pass
# 7    Student 8      99    A+   Pass
# 8    Student 9      44     F   Fail
# 9   Student 10      97    A+   Pass
# 10  Student 11      67    B+   Pass
# 11  Student 12      87     A   Pass
# 12  Student 13      48     F   Fail
# 13  Student 14      93    A+   Pass
# 14  Student 15     100    A+   Pass
# 15  Student 16      59     B   Pass
# 16  Student 17      78    B+   Pass
# 17  Student 18      98    A+   Pass
# 18  Student 19      30     F   Fail
# 19  Student 20      84     A   Pass
# Overall performance:
# Average: 71.2
# Highest mark: 100
# Lowest score: 30

# %%
#QUESTION-1B

import numpy as np
A=np.array([[7,2],[8,4]])
B=np.array([5,6])
x=np.linalg.solve(A,B)
print(x)
# Out:
# [0.66666667 0.16666667]

# %%
#QUESTION-2A

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
steps=[ 6200, 8780, 5670, 19895, 9100, 4560, 7900,9800, 12090, 18900, 18900, 8600, 5294, 7530,8760, 9100, 9600, 4370, 8476, 6857, 9495,10000, 10200, 7567, 6838, 8274, 9775, 8875,56370, 6758]
days=[f"{i}"for i in range(1,31)]
df=pd.DataFrame({'Days':days,'Steps':steps})
print(df)
print("Average steps per day:",df['Steps'].mean())
print("Maximum steps:",df['Steps'].max())
print("Minimum steps:",df['Steps'].min())
HA=[]
for i in range(len(steps)):
  if steps[i]>9000:
    HA.append(i+1)
print("High Activity Days:",HA)
plt.bar(days,steps)
plt.xlabel('Days')
plt.ylabel('Steps')
plt.title('Steps per Day')
plt.show()
# Out:
#    Days  Steps
# 0     1   6200
# 1     2   8780
# 2     3   5670
# 3     4  19895
# 4     5   9100
# 5     6   4560
# 6     7   7900
# 7     8   9800
# 8     9  12090
# 9    10  18900
# 10   11  18900
# 11   12   8600
# 12   13   5294
# 13   14   7530
# 14   15   8760
# 15   16   9100
# 16   17   9600
# 17   18   4370
# 18   19   8476
# 19   20   6857
# 20   21   9495
# 21   22  10000
# 22   23  10200
# 23   24   7567
# 24   25   6838
# 25   26   8274
# 26   27   9775
# 27   28   8875
# 28   29  56370
# 29   30   6758
# Average steps per day: 10817.8
# Maximum steps: 56370
# Minimum steps: 4370
# High Activity Days: [4, 5, 8, 9, 10, 11, 16, 17, 21, 22, 23, 27, 29]

# %%
#QUESTION-2B

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
scores=np.random.randint(30,100,size=(30,3))
subjects=['Math','Science','English']
math=scores[:,0]
science=scores[:,1]
english=scores[:,2]
df=pd.DataFrame({'Student rollno':[f"{i}" for i in range(1,31)],'Math':math,'Science':science,'English':english})
total=[]
for i in range(len(math)):
  total.append(math[i]+science[i]+english[i])
df['Total']=total
print(df)
print("Overall performance:")
print("Average:",df['Total'].mean())
print("Highest mark:",df['Total'].max())
print("Lowest score:",df['Total'].min())
max=0
Top_Score=0
for i in range(len(total)):
  if total[i]>max:
    max=total[i]
    TS=i
print(f"Top performing student:Student {Top_Score}")
plt.bar(df['Student rollno'],df['Math'])
plt.xlabel('Student rollno')
plt.ylabel('Math')
plt.show()
plt.bar(df['Student rollno'],df['Science'])
plt.xlabel('Student rollno')
plt.ylabel('Science')
plt.show()
plt.bar(df['Student rollno'],df['English'])
plt.xlabel('Student rollno')
plt.ylabel('English')
plt.show()
# Out:
#    Student rollno  Math  Science  English  Total
# 0               1    79       32       42    153
# 1               2    76       89       91    256
# 2               3    65       39       92    196
# 3               4    69       95       30    194
# 4               5    97       92       91    280
# 5               6    42       69       67    178
# 6               7    83       62       69    214
# 7               8    79       33       32    144
# 8               9    37       37       71    145
# 9              10    47       50       31    128
# 10             11    98       41       46    185
# 11             12    82       38       52    172
# 12             13    39       73       74    186
# 13             14    68       37       67    172
# 14             15    43       77       97    217
# 15             16    98       98       90    286
# 16             17    94       61       74    229
# 17             18    65       49       79    193
# 18             19    36       67       76    179
# 19             20    38       57       69    164
# 20             21    64       58       31    153
# 21             22    97       78       96    271
# 22             23    77       58       87    222
# 23             24    86       50       41    177
# 24             25    50       78       49    177
# 25             26    41       49       95    185
# 26             27    59       82       32    173
# 27             28    91       39       88    218
# 28             29    31       36       94    161
# 29             30    97       43       68    208
# Overall performance:
# Average: 193.86666666666667
# Highest mark: 286
# Lowest score: 128
# Top performing student:Student 0

# %%
#QUESTION-3A

import cmath
import pandas as pd
def imp(c,v,f):
  w=2*cmath.pi*f
  if c=='R':
    return complex(v,0)
  elif c=='L':
    return complex(0,w*v)
  elif c=='C':
    return complex(0,-1/(w*v))
  else:
    return 'Invalid component'
def tot(df,config):
  if config=='Series':
    return df['Impedance'].sum()
  else:
    return 1 / sum(1 / z for z in df['Impedance'])
f=float(input("Enter Frequency:"))
config=input("Enter the configuration(Series/Parallel):")
n=int(input('No of components:'))
d=[]
for i in range(n):
  c=input("Enter the component(R/L/C):").upper()
  v=float(input("Enter the value:"))
  z=imp(c,v,f)
  d.append({'Component':f'{c}{i+1}','Type':c,'Value': v, 'Impedance': z})
df=pd.DataFrame(d)
pd.set_option("display.precision",2)
print(df)
t=tot(df,config)
print(f'Total Impedance:{t:3.2f}')
# Out:
# Enter Frequency:50
# Enter the configuration(Series/Parallel):Series
# No of components:2
# Enter the component(R/L/C):R
# Enter the value:3
# Enter the component(R/L/C):L
# Enter the value:3
#   Component Type  Value     Impedance
# 0        R1    R    3.0  3.00+  0.00j
# 1        L2    L    3.0  0.00+942.48j
# Total Impedance:3.00+942.48j

# %%
#QUESTION-3B

import numpy as np
stock_1 = np.array([
    [140, 100, 97],
    [122, 100, 88],
    [101, 106, 57],
    [103, 169, 59],
    [104, 109, 60]
])
stock_2 = np.array([
    [98, 104, 94],
    [99, 103, 95],
    [110, 102, 96],
    [101, 195, 97],
    [112, 106, 98]
])
summation=stock_1 + stock_2
difference=stock_1 - stock_2
print("Stock 1:\n",stock_1)
print("\nStock 2 (5x3):\n",stock_2)
print("\nElement-wise Summation:\n",summation)
print("\nElement-wise Difference\n:",difference)
# Out:
# Stock 1:
#  [[140 100  97]
#  [122 100  88]
#  [101 106  57]
#  [103 169  59]
#  [104 109  60]]
#
# Stock 2 (5x3):
#  [[ 98 104  94]
#  [ 99 103  95]
#  [110 102  96]
#  [101 195  97]
#  [112 106  98]]
#
# Element-wise Summation:
#  [[238 204 191]
#  [221 203 183]
#  [211 208 153]
#  [204 364 156]
#  [216 215 158]]
#
# Element-wise Difference
# : [[ 42  -4   3]
#  [ 23  -3  -7]
#  [ -9   4 -39]
#  [  2 -26 -38]
#  [ -8   3 -38]]

# %%
#QUESTION-4A

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
sampling_rate = 50  # Hz
duration = 1  # in seconds
t = np.linspace(0, duration, int(sampling_rate * duration), endpoint=False)
def generate_wave(freq, amp, noise_level):
    signal = amp * np.sin(2 * np.pi * freq * t)
    noise = np.random.normal(0, noise_level, t.shape)
    return signal + noise
data={
    'Patient_No':[f"{i}" for i in range(1,51)],
    'Time(s)':t,
    'Delta waves': generate_wave(2, 10, 10),
    'Theta waves': generate_wave(6, 6, 8),
    'Alpha waves': generate_wave(10, 4, 5),
    'Beta waves':  generate_wave(20, 5, 3)
}
df = pd.DataFrame(data)
df.to_csv(r"C:\Users\DELL\Downloads\EEG-Sheet1.csv",index=False)
print(df)
print("\nStatistics (Mean, Variance, Max):")
print('Mean:\n',df[['Delta waves', 'Theta waves', 'Alpha waves', 'Beta waves']].mean())
print('Variance:\n',df[['Delta waves', 'Theta waves', 'Alpha waves', 'Beta waves']].var())
print('Max:\n',df[['Delta waves', 'Theta waves', 'Alpha waves', 'Beta waves']].max())
plt.bar(df['Patient_No'],df['Delta waves'])
plt.xlabel('Patient_No')
plt.ylabel('Delta')
plt.show()
plt.bar(df['Patient_No'],df['Theta waves'])
plt.xlabel('Patient_No')
plt.ylabel('Theta')
plt.show()
plt.bar(df['Patient_No'],df['Alpha waves'])
plt.xlabel('Patient_No')
plt.ylabel('Alpha')
plt.show()
plt.bar(df['Patient_No'],df['Beta waves'])
plt.xlabel('Patient_No')
plt.ylabel('Beta waves')
plt.show()
# Out:
#    Patient_No  Time(s)  Delta waves  Theta waves  Alpha waves  Beta waves
# 0           1     0.00   -26.155258     0.134151    -9.491943    4.076374
# 1           2     0.02     2.331725    -7.746981     8.304610    0.667407
# 2           3     0.04   -14.533116    -0.263050     4.320375    1.693649
# 3           4     0.06    -5.321109    -5.438954     5.303032   -4.428857
# 4           5     0.08    -9.457240     1.332256    -7.390350   -1.914606
# 5           6     0.10     7.196919    -8.629324   -14.350678   -0.630261
# 6           7     0.12    11.023395    -5.765121     6.730090    0.620114
# 7           8     0.14    21.236383    -1.221563    -6.342063   -3.689198
# 8           9     0.16     8.149993     6.138503     2.565602    1.095925
# 9          10     0.18     9.825510     8.921741     3.716594   -2.479087
# 10         11     0.20     2.475099    -0.077260    -8.923193    1.219709
# 11         12     0.22    -7.178027   -11.554433     3.218620    4.180408
# 12         13     0.24   -11.986720    10.502353     3.719577    2.591734
# 13         14     0.26    17.578847    -4.495782    -0.767778    1.711312
# 14         15     0.28    -2.888630     1.095520     2.891887   -2.587496
# 15         16     0.30     7.996327     2.687310     8.533658    3.073477
# 16         17     0.32    -7.926265   -12.443788     3.882908    3.336610
# 17         18     0.34    -4.026740    -0.152511     9.133307   -3.087863
# 18         19     0.36   -20.098301     6.218470    -7.288376    3.089989
# 19         20     0.38   -18.955767     8.186157    -8.659327   -4.372640
# 20         21     0.40    -6.344595     3.234839     1.883990    0.499602
# 21         22     0.42   -11.318495    -7.186810     7.668916    0.956504
# 22         23     0.44    -0.664695     1.924896     3.880276   -2.489570
# 23         24     0.46    -2.536904    -3.647792     7.664218    3.468421
# 24         25     0.48    14.120290     4.444406   -10.476762   -1.502319
# 25         26     0.50   -12.667473     6.924313    -0.417238   -1.990026
# 26         27     0.52    -3.516969     8.748051    15.394993    2.359194
# 27         28     0.54    11.878321     7.492213     1.507185   -6.031685
# 28         29     0.56    12.105271    -8.117196    -2.134888    7.851473
# 29         30     0.58    -2.694363     0.848615    -6.885093   -0.661253
# 30         31     0.60    10.946540    -2.755591   -10.536249   -3.335191
# 31         32     0.62     5.834932   -21.453002     1.247190   -2.476332
# 32         33     0.64     5.695517    -1.431382    -5.998505   -5.388513
# 33         34     0.66     6.716434    -4.255827     6.717354    2.125292
# 34         35     0.68    14.853445     4.330267    -6.253817    1.287429
# 35         36     0.70    14.433602     2.707408     0.610616   -0.923337
# 36         37     0.72     7.081577    18.729051     6.986289    1.921249
# 37         38     0.74    22.808381     9.293920    -5.618764   -7.974739
# 38         39     0.76    -3.620307    -1.397652     0.260125    2.405096
# 39         40     0.78     4.218189   -12.035137    -4.452303   -1.419795
# 40         41     0.80    -4.212862    -9.195046    -1.849068    2.784366
# 41         42     0.82     2.087404    -4.959875     7.449120   -2.046476
# 42         43     0.84   -17.348091    -0.278180     5.639034   -5.606416
# 43         44     0.86     2.463878     8.469769     0.736973    0.837463
# 44         45     0.88     0.778081    19.941284   -13.178569   -6.732627
# 45         46     0.90    -1.926964     4.797417    -1.263925   -1.882411
# 46         47     0.92   -12.630238    13.685922     7.734847    6.450320
# 47         48     0.94    -9.499863   -16.024363     5.866209   -7.320947
# 48         49     0.96    -5.349421    -3.233906    -2.387683    5.244677
# 49         50     0.98    -8.163152     3.252929    -5.970477   -5.299858
#
# Statistics (Mean, Variance, Max):
# Mean:
#  Delta waves   -0.143710
# Theta waves    0.205625
# Alpha waves    0.058611
# Beta waves    -0.414474
# dtype: float64
# Variance:
#  Delta waves    122.696543
# Theta waves     68.565083
# Alpha waves     46.065574
# Beta waves      13.310959
# dtype: float64
# Max:
#  Delta waves    22.808381
# Theta waves    19.941284
# Alpha waves    15.394993
# Beta waves      7.851473
# dtype: float64

# %%
#QUESTION-4B

import matplotlib.pyplot as plt
d={'Product':['Laptop','Smartphone','Tablet','Monitor','Keyboard'],'Price':[1200,800,300,150,50],'Quantity':[10, 20, 15, 25, 50]}
df=pd.DataFrame(d)
df['Total']=df['Price']*df['Quantity']
print("Average:",df['Total'].mean())
print("Highest Price:",df['Price'].max())
print("Lowest Price:",df['Price'].min())
plt.bar(df['Product'],df['Price'])
plt.xlabel('Product')
plt.ylabel('Price')
plt.show()
plt.pie(df['Quantity'],labels=df['Product'])
plt.title('Quantity Distribution')
plt.show()
# Out:
# Average: 7750.0
# Highest Price: 1200
# Lowest Price: 50

# %%
#QUESTION-5A

import pandas as pd
sheet_id = '1jVHGkKb1P_iwZAbbQ98aUUWVIJAfPUeksIwifQeY1ao'
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv"
df = pd.read_csv(url)
print(df)
k=df.ffill()
print(k)
x=k['Month']
y=k['Sales(%)']
plt.xlabel('Month')
plt.ylabel('Sales(%)')
plt.plot(x,y)
plt.show()
# Out:
#         Month  Sales(%)
# 0     January      90.0
# 1     Febrary      70.0
# 2       March      68.0
# 3       April      79.0
# 4         May       NaN
# 5        June      88.0
# 6        July      77.0
# 7      August      66.0
# 8   September      88.0
# 9     October      76.0
# 10   November      77.0
# 11   December      94.0
#         Month  Sales(%)
# 0     January      90.0
# 1     Febrary      70.0
# 2       March      68.0
# 3       April      79.0
# 4         May      79.0
# 5        June      88.0
# 6        July      77.0
# 7      August      66.0
# 8   September      88.0
# 9     October      76.0
# 10   November      77.0
# 11   December      94.0

# %%
#QUESTION-5B

import pandas as pd
sheet_id ='1y1sLJE-CYg-MhhctnLj9rC8cKw7f3ZUh5-sVSoTebfY'
url=f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv"
df=pd.read_csv(url)
print(df)
print("Column names and data types:")
print(df.dtypes)
avg=df['Age'].mean()
print("\nAverage Age of the Patients:",avg)
y=df['Diagnosis'].value_counts()
plt.bar(y.index,y.values)
plt.xlabel('Diagnosis')
plt.ylabel('Frequency')
plt.show()
# Out:
#     PatientID  Age  Gender     Diagnosis             Medical History
# 0           1   34  Female       Healthy                     Obesity
# 1           2   30  Female  Hypertension  Family history of diabetes
# 2           3   43    Male        Asthma                     Obesity
# 3           4   64  Female        Asthma                      Smoker
# 4           5   73    Male        Cancer                         NaN
# ..        ...  ...     ...           ...                         ...
# 95         96   55  Female      Diabetes                         NaN
# 96         97   39    Male  Hypertension                      Smoker
# 97         98   31  Female        Cancer                         NaN
# 98         99   50    Male        Asthma                         NaN
# 99        100   76  Female        Cancer                Chronic pain
#
# [100 rows x 5 columns]
# Column names and data types:
# PatientID           int64
# Age                 int64
# Gender             object
# Diagnosis          object
# Medical History    object
# dtype: object
#
# Average Age of the Patients: 50.39
